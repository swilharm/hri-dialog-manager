# %% [markdown]
# # 1. Import Dependencies

# %%
#!pip install -q stable-baselines3[extra]

# %%
import numpy as np
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete
from stable_baselines3 import PPO
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 3. Building an Environment

# %%
X_df = pd.read_json('data/X_DM.json', orient='index')
y_df = pd.DataFrame(pd.read_json('data/y_DM.json').values.T)
df_new = X_df.drop(['Instruction', 'Coordinate'], axis=1)
instr_df = pd.DataFrame(df_new['Instruction Confidence'].to_list())
coord_df = pd.DataFrame(df_new['Coordinate Confidence'].to_list())
coord_df0 = pd.DataFrame(coord_df[0].to_list())
coord_df1 = pd.DataFrame(coord_df[1].to_list())

# column name
no_puzzlepieces = 15
a = [f'Instr{i}' for i in range(3)]
b = [f'LV{i}' for i in range(no_puzzlepieces)]
c = [f'G{i}' for i in range(no_puzzlepieces)]

col_names = []
col_names.extend(a)
col_names.extend(b)
col_names.extend(c)

final_df_noisy = pd.concat([instr_df, coord_df0, coord_df1], axis=1)
final_df_noisy.columns = col_names

# Tensorize X and y
model1_X = final_df_noisy.values
model1_y = y_df.values

train1_X, test1_X, train1_y, test1_y = train_test_split(model1_X[:100000], model1_y[:100000], test_size=1/3, random_state=42)

# %%
class ActionEnv(Env):
    def __init__(self):
        # number of pentomino pieces
        no_pieces = 15 + 1 + 1 #pieces + do nothing + lang team
        
        # ACTIONS
        '''for now: we only decide for one coordinate --> no of actions = number of coordinates)
        (for later: we only decide for one coordinate out of all absolute coordinates and moving coordinate, 
        boolean value expressing uncertainty)'''
        self.action_space = Discrete(no_pieces)
        
        # Temperature array
        self.observation_space = Box(low=0, high=1, shape=(train1_X.shape[1],))

        # POSSIBLE STATES
        '''Set start state (in our case start state is the only state and here we need to get our training data in or
        construct a random formula that will randomly generate possible scenarios each time the function is called.
        for now: create random probabilities for 9 coordinates that add up to one
        uplevel: do the same and make sure that all follow the true distribution which is p=1 for the gold_coordinate and p=0 for all others
        uplevel: do the same + add possiblity for moving vector'''
        self.state  = train1_X[i]
        self.p_gold = train1_y[i]
 
        
    def step(self, action):
        '''Our actions do not affect our state, because we only have one state, the start state. Also we don't need 
        the shower_length which represents the lenght of the sequence, but at the end we use it in the evalulation-
        function soo .. dunno.
        '''
    

        if action == self.p_gold:
            reward = 1
        else:
            reward = -1
        
        # Check if sequence is done
        '''we have a sequence of one state: the output that the other groups give us. based on that 
        we make a decision and a new round starts. so we don't need to count down the seconds of a 60min long
        shower to know when a round is over.'''
        done = True
        
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self):
        # Implement viz
        pass
    
    def reset(self):
        '''Reset start state (output of previous groups) when new round starts (use "random-formula" that we need to 
        create above)'''
        global i
        self.state = train1_X[i]
        self.p_gold = train1_y[i]
        i += 1
        if i == len(train1_X):
            i = 0

        return self.state

# %% [markdown]
# # 5. Train Model

# %%
model1 = PPO("MlpPolicy", ActionEnv(), verbose=1)
model1.learn(total_timesteps=200000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.98    |
# | time/              |          |
# |    fps             | 1407     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.72       |
# | time/                   |             |
# |    fps                  | 987         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.101924926 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | -0.00684    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0464      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0435     |
# |    value_loss           | 0.258       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.52       |
# | time/                   |             |
# |    fps                  | 884         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.085634075 |
# |    clip_fraction        | 0.537       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.39       |
# |    explained_variance   | 0.00459     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0628      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.101      |
# |    value_loss           | 0.503       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.04       |
# | time/                   |             |
# |    fps                  | 850         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.096424386 |
# |    clip_fraction        | 0.64        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.138      |
# |    value_loss           | 0.656       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.14       |
# | time/                   |            |
# |    fps                  | 829        |
# |    iterations           | 5          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.26030833 |
# |    clip_fraction        | 0.466      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.381      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.149      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.127     |
# |    value_loss           | 0.585      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.24       |
# | time/                   |            |
# |    fps                  | 817        |
# |    iterations           | 6          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01941932 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.666      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.106      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0537    |
# |    value_loss           | 0.269      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.14        |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.022095177 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0647      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0606     |
# |    value_loss           | 0.223       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.2        |
# | time/                   |            |
# |    fps                  | 801        |
# |    iterations           | 8          |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02188063 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.807      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0345     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0299    |
# |    value_loss           | 0.148      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 9           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007221043 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.079       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 0.0883      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.14         |
# | time/                   |              |
# |    fps                  | 793          |
# |    iterations           | 10           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0071098385 |
# |    clip_fraction        | 0.0986       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.995       |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0128       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0168      |
# |    value_loss           | 0.104        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.42        |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 11          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006791414 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00208     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.104       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.38         |
# | time/                   |              |
# |    fps                  | 744          |
# |    iterations           | 12           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0056396555 |
# |    clip_fraction        | 0.0679       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.986       |
# |    explained_variance   | 0.898        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.024        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0132      |
# |    value_loss           | 0.0947       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.36         |
# | time/                   |              |
# |    fps                  | 740          |
# |    iterations           | 13           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0058857356 |
# |    clip_fraction        | 0.0826       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.94        |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0418       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.016       |
# |    value_loss           | 0.0814       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 741         |
# |    iterations           | 14          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006623272 |
# |    clip_fraction        | 0.0944      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.875      |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 0.114       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 15          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009577843 |
# |    clip_fraction        | 0.0836      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0429      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 0.101       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.24         |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 16           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0046124477 |
# |    clip_fraction        | 0.0687       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | 0.891        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0661       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0156      |
# |    value_loss           | 0.097        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.38        |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 17          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005873221 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0374      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 0.102       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.24         |
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 18           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0055189077 |
# |    clip_fraction        | 0.065        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.897       |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0367       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0154      |
# |    value_loss           | 0.0879       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.14        |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 19          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005334491 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0374      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 0.0951      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.46         |
# | time/                   |              |
# |    fps                  | 701          |
# |    iterations           | 20           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0044289525 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.92        |
# |    explained_variance   | 0.815        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0454       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0212      |
# |    value_loss           | 0.17         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.26        |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 21          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008001451 |
# |    clip_fraction        | 0.0518      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.791      |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0492      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 0.104       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.18         |
# | time/                   |              |
# |    fps                  | 703          |
# |    iterations           | 22           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0050961524 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.799       |
# |    explained_variance   | 0.856        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0115       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0208      |
# |    value_loss           | 0.127        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.48         |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 23           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0059616137 |
# |    clip_fraction        | 0.0554       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.81        |
# |    explained_variance   | 0.835        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0219       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0216      |
# |    value_loss           | 0.145        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.24        |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 24          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004275349 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.743      |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0403      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 0.149       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.34         |
# | time/                   |              |
# |    fps                  | 713          |
# |    iterations           | 25           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0059358515 |
# |    clip_fraction        | 0.0802       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.772       |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0462       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0212      |
# |    value_loss           | 0.161        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.44         |
# | time/                   |              |
# |    fps                  | 716          |
# |    iterations           | 26           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0057232752 |
# |    clip_fraction        | 0.0747       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.71        |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0401       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0193      |
# |    value_loss           | 0.145        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.44         |
# | time/                   |              |
# |    fps                  | 719          |
# |    iterations           | 27           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0065602493 |
# |    clip_fraction        | 0.0825       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.746       |
# |    explained_variance   | 0.794        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0963       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0182      |
# |    value_loss           | 0.173        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.38         |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 28           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0055676987 |
# |    clip_fraction        | 0.0682       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.707       |
# |    explained_variance   | 0.815        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0407       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0171      |
# |    value_loss           | 0.158        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.26         |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 29           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0058102375 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.659       |
# |    explained_variance   | 0.814        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0172       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0168      |
# |    value_loss           | 0.153        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 30          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.005466805 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.696      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0335      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 0.163       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 31          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.005013546 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.041       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 0.175       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.46        |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 32          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004870325 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0516      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.164       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.56         |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 33           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0049685477 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.594       |
# |    explained_variance   | 0.815        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0119      |
# |    value_loss           | 0.149        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.42         |
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 34           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0042842347 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.604       |
# |    explained_variance   | 0.788        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.061        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0132      |
# |    value_loss           | 0.172        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.52         |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 35           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0072101634 |
# |    clip_fraction        | 0.0826       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.793        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0681       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0149      |
# |    value_loss           | 0.162        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.52         |
# | time/                   |              |
# |    fps                  | 732          |
# |    iterations           | 36           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0026770388 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.581       |
# |    explained_variance   | 0.798        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0619       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0098      |
# |    value_loss           | 0.161        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 37          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.003971337 |
# |    clip_fraction        | 0.0549      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0667      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.153       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.48         |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 38           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0057165925 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.554       |
# |    explained_variance   | 0.779        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0477       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0141      |
# |    value_loss           | 0.171        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.52         |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 39           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0044638435 |
# |    clip_fraction        | 0.0461       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.536       |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.102        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0139      |
# |    value_loss           | 0.175        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.5          |
# | time/                   |              |
# |    fps                  | 739          |
# |    iterations           | 40           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0041600307 |
# |    clip_fraction        | 0.0707       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.55        |
# |    explained_variance   | 0.799        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0871       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 0.16         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.48         |
# | time/                   |              |
# |    fps                  | 741          |
# |    iterations           | 41           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0047978936 |
# |    clip_fraction        | 0.056        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.562       |
# |    explained_variance   | 0.787        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0643       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0142      |
# |    value_loss           | 0.167        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.5          |
# | time/                   |              |
# |    fps                  | 743          |
# |    iterations           | 42           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0057674367 |
# |    clip_fraction        | 0.0673       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0144      |
# |    value_loss           | 0.178        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.44        |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 43          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006128002 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.521      |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0551      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.176       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.42         |
# | time/                   |              |
# |    fps                  | 746          |
# |    iterations           | 44           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0054842373 |
# |    clip_fraction        | 0.0639       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.513       |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0694       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 0.179        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.46         |
# | time/                   |              |
# |    fps                  | 747          |
# |    iterations           | 45           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0046413587 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.534       |
# |    explained_variance   | 0.775        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0259       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 0.177        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.36         |
# | time/                   |              |
# |    fps                  | 749          |
# |    iterations           | 46           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0036615925 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.447       |
# |    explained_variance   | 0.772        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.061        |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0111      |
# |    value_loss           | 0.161        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.28         |
# | time/                   |              |
# |    fps                  | 750          |
# |    iterations           | 47           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0042678434 |
# |    clip_fraction        | 0.0506       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | 0.798        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0367       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00948     |
# |    value_loss           | 0.159        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.42         |
# | time/                   |              |
# |    fps                  | 752          |
# |    iterations           | 48           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0038274545 |
# |    clip_fraction        | 0.0483       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.483       |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.061        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00962     |
# |    value_loss           | 0.153        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.36         |
# | time/                   |              |
# |    fps                  | 753          |
# |    iterations           | 49           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0040149936 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.477       |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0802       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 0.153        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.38        |
# | time/                   |             |
# |    fps                  | 754         |
# |    iterations           | 50          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.004644117 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.507      |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0935      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00918    |
# |    value_loss           | 0.171       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.46        |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 51          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.004154329 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.451      |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0339      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00936    |
# |    value_loss           | 0.173       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.66         |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 52           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0043640425 |
# |    clip_fraction        | 0.0649       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.475       |
# |    explained_variance   | 0.795        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0577       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0117      |
# |    value_loss           | 0.158        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.48        |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 53          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.003626076 |
# |    clip_fraction        | 0.061       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.481      |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0719      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.176       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 54          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.005606206 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.427      |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0435      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 758         |
# ...
# |    ep_rew_mean          | 0.56         |
# | time/                   |              |
# |    fps                  | 776          |
# |    iterations           | 81           |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0041619968 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.341       |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0504       |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.0151      |
# |    value_loss           | 0.185        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.62       |
# | time/                   |            |
# |    fps                  | 776        |
# |    iterations           | 82         |
# |    time_elapsed         | 216        |
# |    total_timesteps      | 167936     |
# | train/                  |            |
# |    approx_kl            | 0.00595134 |
# |    clip_fraction        | 0.0537     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.361     |
# |    explained_variance   | 0.692      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.128      |
# |    n_updates            | 810        |
# |    policy_gradient_loss | -0.0139    |
# |    value_loss           | 0.198      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.62         |
# | time/                   |              |
# |    fps                  | 776          |
# |    iterations           | 83           |
# |    time_elapsed         | 218          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0067303614 |
# |    clip_fraction        | 0.0586       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.363       |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0448       |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.0138      |
# |    value_loss           | 0.197        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.64         |
# | time/                   |              |
# |    fps                  | 777          |
# |    iterations           | 84           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0041396217 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.332       |
# |    explained_variance   | 0.728        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0714       |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.0133      |
# |    value_loss           | 0.173        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.7          |
# | time/                   |              |
# |    fps                  | 777          |
# |    iterations           | 85           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0055824844 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.362       |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0637       |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.0121      |
# |    value_loss           | 0.21         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.62         |
# | time/                   |              |
# |    fps                  | 777          |
# |    iterations           | 86           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0040759956 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.33        |
# |    explained_variance   | 0.705        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0811       |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 0.187        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.6          |
# | time/                   |              |
# |    fps                  | 778          |
# |    iterations           | 87           |
# |    time_elapsed         | 228          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0056684753 |
# |    clip_fraction        | 0.0591       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.305       |
# |    explained_variance   | 0.679        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.0127      |
# |    value_loss           | 0.183        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.52        |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 88          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.011276052 |
# |    clip_fraction        | 0.0668      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.328      |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0312      |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 0.164       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.64         |
# | time/                   |              |
# |    fps                  | 779          |
# |    iterations           | 89           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0037659972 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.3         |
# |    explained_variance   | 0.659        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0702       |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.012       |
# |    value_loss           | 0.2          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.58         |
# | time/                   |              |
# |    fps                  | 779          |
# |    iterations           | 90           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0045679896 |
# |    clip_fraction        | 0.0429       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.31        |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0738       |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00809     |
# |    value_loss           | 0.18         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.64         |
# | time/                   |              |
# |    fps                  | 779          |
# |    iterations           | 91           |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0035584858 |
# |    clip_fraction        | 0.0534       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.311       |
# |    explained_variance   | 0.706        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0777       |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.178        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 780         |
# |    iterations           | 92          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.005129732 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.313      |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0859      |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.178       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.66         |
# | time/                   |              |
# |    fps                  | 780          |
# |    iterations           | 93           |
# |    time_elapsed         | 244          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0053287586 |
# |    clip_fraction        | 0.0533       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.318       |
# |    explained_variance   | 0.71         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0581       |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 0.177        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.56         |
# | time/                   |              |
# |    fps                  | 780          |
# |    iterations           | 94           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0036499295 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.292       |
# |    explained_variance   | 0.706        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.1          |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 0.165        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.48        |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 95          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.008625377 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.32       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0804      |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.176       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.68         |
# | time/                   |              |
# |    fps                  | 781          |
# |    iterations           | 96           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0038402975 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.331       |
# |    explained_variance   | 0.694        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0706       |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.009       |
# |    value_loss           | 0.19         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.58         |
# | time/                   |              |
# |    fps                  | 781          |
# |    iterations           | 97           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0040880847 |
# |    clip_fraction        | 0.0585       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.315       |
# |    explained_variance   | 0.683        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.104        |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0135      |
# |    value_loss           | 0.193        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.54        |
# | time/                   |             |
# |    fps                  | 782         |
# |    iterations           | 98          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.004475881 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.288      |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0493      |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.169       |
# -----------------------------------------

# %%
#model1.save('RL_action_model')

# %% [markdown]
# # Evaluation

# %%
i = 0
model1 = PPO.load('RL_action_model', ActionEnv())
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
correct = 0
for i in range(len(test1_X)):
    obs = test1_X[i]
    p_gold = test1_y[i]
    pred, _ = model1.predict(obs)
    if pred==p_gold:
        correct += 1
accuracy = correct/len(test1_X)
print(accuracy)
# Out:
# 0.8139737205255895

# %% [markdown]
# # Model 2

# %%
model2_y = np.ones((100000,))
for i in range(100000, 200000):
    obs = model1_X[i]
    p_gold = model1_y[i]
    pred, _ = model1.predict(obs)
    if pred==p_gold:
        model2_y[i-100000] = 0

# %%
train2_X, test2_X, train2_y, test2_y = train_test_split(model1_X[100000:], model2_y, test_size=1/3, random_state=42)

# %%
class UncertaintyEnv(Env):
    def __init__(self):
        # ACTIONS
        '''for now: we only decide for one coordinate --> no of actions = number of coordinates)
        (for later: we only decide for one coordinate out of all absolute coordinates and moving coordinate,
        boolean value expressing uncertainty)'''
        self.action_space = Discrete(2)

        # Temperature array
        self.observation_space = Box(low=0, high=1, shape=(train2_X.shape[1],))

        # POSSIBLE STATES
        '''Set start state (in our case start state is the only state and here we need to get our training data in or
        construct a random formula that will randomly generate possible scenarios each time the function is called.
        for now: create random probabilities for 9 coordinates that add up to one
        uplevel: do the same and make sure that all follow the true distribution which is p=1 for the gold_coordinate and p=0 for all others
        uplevel: do the same + add possiblity for moving vector'''
        self.state  = train2_X[i]
        self.p_gold = train2_y[i]


    def step(self, action):
        '''Our actions do not affect our state, because we only have one state, the start state. Also we don't need
        the shower_length which represents the lenght of the sequence, but at the end we use it in the evalulation-
        function soo .. dunno.
        '''


        if action == self.p_gold:
            reward = 1
        else:
            reward = -1

        # Check if sequence is done
        '''we have a sequence of one state: the output that the other groups give us. based on that
        we make a decision and a new round starts. so we don't need to count down the seconds of a 60min long
        shower to know when a round is over.'''
        done = True

        info = {}

        # Return step information
        return self.state, reward, done, info

    def render(self):
        # Implement viz
        pass

    def reset(self):
        '''Reset start state (output of previous groups) when new round starts (use "random-formula" that we need to
        create above)'''
        global i
        self.state = train2_X[i]
        self.p_gold = train2_y[i]
        i += 1
        if i == len(train2_X):
            i = 0

        return self.state

# %%
i = 0
model2 = PPO("MlpPolicy", UncertaintyEnv(), verbose=1)
model2.learn(total_timesteps=200000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.14     |
# | time/              |          |
# |    fps             | 1501     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.28        |
# | time/                   |             |
# |    fps                  | 1053        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.044250324 |
# |    clip_fraction        | 0.568       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | -0.0221     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.41        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.112      |
# |    value_loss           | 1           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.44        |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.077541426 |
# |    clip_fraction        | 0.628       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.524      |
# |    explained_variance   | 0.00157     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.366       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.123      |
# |    value_loss           | 0.942       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.64       |
# | time/                   |            |
# |    fps                  | 917        |
# |    iterations           | 4          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.19782451 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.33      |
# |    explained_variance   | 0.0935     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.206      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.093     |
# |    value_loss           | 0.713      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.78        |
# | time/                   |             |
# |    fps                  | 890         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.026209176 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.237      |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.108       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0468     |
# |    value_loss           | 0.453       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.8         |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008865928 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.189      |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.154       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 0.377       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.78        |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007274801 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.172      |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.143       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 0.362       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.88         |
# | time/                   |              |
# |    fps                  | 776          |
# |    iterations           | 8            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0033393358 |
# |    clip_fraction        | 0.023        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.146       |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.185        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 0.293        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.8          |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 9            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0040557487 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.126       |
# |    explained_variance   | 0.136        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.074        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00965     |
# |    value_loss           | 0.303        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.9         |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 10          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004906185 |
# |    clip_fraction        | 0.0384      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.114      |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0077     |
# |    value_loss           | 0.279       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.84         |
# | time/                   |              |
# |    fps                  | 686          |
# |    iterations           | 11           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0024894415 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.103       |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00764     |
# |    value_loss           | 0.273        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.88        |
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 12          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.001848001 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.099      |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.213       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00469    |
# |    value_loss           | 0.251       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.8         |
# | time/                   |             |
# |    fps                  | 688         |
# |    iterations           | 13          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.002247631 |
# |    clip_fraction        | 0.0263      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0949     |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.126       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00155     |
# |    value_loss           | 0.227       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.84         |
# | time/                   |              |
# |    fps                  | 686          |
# |    iterations           | 14           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0012664684 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0932      |
# |    explained_variance   | 0.115        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0982       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 0.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.82         |
# | time/                   |              |
# |    fps                  | 688          |
# |    iterations           | 15           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0021488543 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0941      |
# |    explained_variance   | 0.163        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0835       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 0.282        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.86        |
# | time/                   |             |
# |    fps                  | 686         |
# |    iterations           | 16          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.002220878 |
# |    clip_fraction        | 0.0255      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.092      |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0557      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.000947    |
# |    value_loss           | 0.242       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.86         |
# | time/                   |              |
# |    fps                  | 686          |
# |    iterations           | 17           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0041217743 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0821      |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0707       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00582     |
# |    value_loss           | 0.241        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.86         |
# | time/                   |              |
# |    fps                  | 692          |
# |    iterations           | 18           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0021356565 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0776      |
# |    explained_variance   | 0.185        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0604       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 0.227        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.88         |
# | time/                   |              |
# |    fps                  | 698          |
# |    iterations           | 19           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0033916489 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0767      |
# |    explained_variance   | 0.18         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0828       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 0.235        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.82         |
# | time/                   |              |
# |    fps                  | 704          |
# |    iterations           | 20           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0016057168 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0704      |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0405       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.00191      |
# |    value_loss           | 0.209        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 708          |
# |    iterations           | 21           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0018650761 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0649      |
# |    explained_variance   | 0.163        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.178        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 0.216        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.86         |
# | time/                   |              |
# |    fps                  | 710          |
# |    iterations           | 22           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0021564786 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.059       |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0803       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00296     |
# |    value_loss           | 0.206        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.86         |
# | time/                   |              |
# |    fps                  | 715          |
# |    iterations           | 23           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0026824228 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0697      |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.176        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.000855     |
# |    value_loss           | 0.231        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.82         |
# | time/                   |              |
# |    fps                  | 712          |
# |    iterations           | 24           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0018936758 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0676      |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.107        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.00155      |
# |    value_loss           | 0.228        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | 0.86          |
# | time/                   |               |
# |    fps                  | 713           |
# |    iterations           | 25            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00091183913 |
# |    clip_fraction        | 0.0134        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0656       |
# |    explained_variance   | 0.179         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0546        |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.0016       |
# |    value_loss           | 0.24          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.9          |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 26           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0014538489 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0639      |
# |    explained_variance   | 0.156        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.113        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.00231      |
# |    value_loss           | 0.22         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.82         |
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 27           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0012532556 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0617      |
# |    explained_variance   | 0.137        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.107        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 0.215        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.88        |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 28          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004346635 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0675     |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0768      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00581    |
# |    value_loss           | 0.255       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 726          |
# |    iterations           | 29           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0014120727 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0712      |
# |    explained_variance   | 0.171        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.129        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 0.235        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | 0.86          |
# | time/                   |               |
# |    fps                  | 728           |
# |    iterations           | 30            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00083754474 |
# |    clip_fraction        | 0.014         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0634       |
# |    explained_variance   | 0.162         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0709        |
# |    n_updates            | 290           |
# |    policy_gradient_loss | 0.00123       |
# |    value_loss           | 0.212         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.9          |
# | time/                   |              |
# |    fps                  | 731          |
# |    iterations           | 31           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0020647293 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0684      |
# |    explained_variance   | 0.177        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0705       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 0.215        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.86        |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 32          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.002419366 |
# |    clip_fraction        | 0.0179      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0681     |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0678      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00149    |
# |    value_loss           | 0.22        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.78         |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 33           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0020238748 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0683      |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.101        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00378     |
# |    value_loss           | 0.233        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.92        |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 34          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.001694328 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0676     |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0407      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.000238    |
# |    value_loss           | 0.233       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.9          |
# | time/                   |              |
# |    fps                  | 739          |
# |    iterations           | 35           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0014369239 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0631      |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0684       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.000412     |
# |    value_loss           | 0.204        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.88         |
# | time/                   |              |
# |    fps                  | 741          |
# |    iterations           | 36           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0011371593 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0625      |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.114        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.000298     |
# |    value_loss           | 0.209        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.82        |
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 37          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.002721137 |
# |    clip_fraction        | 0.0154      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0624     |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0349      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00011     |
# |    value_loss           | 0.216       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.88         |
# | time/                   |              |
# |    fps                  | 745          |
# |    iterations           | 38           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0063578393 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0659      |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0874       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00185     |
# |    value_loss           | 0.216        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.86         |
# | time/                   |              |
# |    fps                  | 747          |
# |    iterations           | 39           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0012660829 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0679      |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0861       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000918    |
# |    value_loss           | 0.215        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.86         |
# | time/                   |              |
# |    fps                  | 748          |
# |    iterations           | 40           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0035552075 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0709      |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.109        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 0.216        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.72         |
# | time/                   |              |
# |    fps                  | 750          |
# |    iterations           | 41           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0010311712 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0681      |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0688       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000738    |
# |    value_loss           | 0.218        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.84         |
# | time/                   |              |
# |    fps                  | 752          |
# |    iterations           | 42           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0034657456 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0745      |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.135        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 0.241        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.9        |
# | time/                   |            |
# |    fps                  | 753        |
# |    iterations           | 43         |
# |    time_elapsed         | 116        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.00183025 |
# |    clip_fraction        | 0.0222     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0677    |
# |    explained_variance   | 0.142      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.15       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | 0.00128    |
# |    value_loss           | 0.217      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 755          |
# |    iterations           | 44           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0014093474 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0625      |
# |    explained_variance   | 0.17         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.153        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 0.199        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.86         |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 45           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0021319755 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0673      |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0888       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 0.201        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.9         |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 46          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.002321774 |
# |    clip_fraction        | 0.0231      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0638     |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0865      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 0.208       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.72        |
# | time/                   |             |
# |    fps                  | 759         |
# |    iterations           | 47          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.002221747 |
# |    clip_fraction        | 0.0243      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0663     |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0512      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00246     |
# |    value_loss           | 0.24        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 760          |
# |    iterations           | 48           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0046011843 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0636      |
# |    explained_variance   | 0.163        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0763       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 0.22         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.84        |
# | time/                   |             |
# |    fps                  | 762         |
# |    iterations           | 49          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.001499129 |
# |    clip_fraction        | 0.0206      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0669     |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.156       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0023     |
# |    value_loss           | 0.223       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.82        |
# | time/                   |             |
# |    fps                  | 763         |
# |    iterations           | 50          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.000931005 |
# |    clip_fraction        | 0.0154      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0589     |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0288      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00224    |
# |    value_loss           | 0.207       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.88         |
# | time/                   |              |
# |    fps                  | 764          |
# |    iterations           | 51           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0018259176 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.061       |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0509       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000252    |
# |    value_loss           | 0.208        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.86         |
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 52           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0010503251 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0601      |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.162        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000458    |
# |    value_loss           | 0.198        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 53           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0021163928 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0582      |
# |    explained_variance   | 0.151        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0983       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 0.212        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | 0.88          |
# | time/                   |               |
# |    fps                  | 768           |
# |    iterations           | 54            |
# |    time_elapsed         | 143           |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 0.00084637746 |
# |    clip_fraction        | 0.018         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0538       |
# |    explained_variance   | 0.115         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0237        |
# |    n_updates            | 530           |
# |    policy_gradient_loss | 0.00337       |
# |    value_loss           | 0.169         |
# -------------------------------------------
# ------------------------------------------
# ...
# | time/                   |              |
# |    fps                  | 782          |
# |    iterations           | 81           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0030588703 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0532      |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.166        |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.000575    |
# |    value_loss           | 0.186        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.86         |
# | time/                   |              |
# |    fps                  | 783          |
# |    iterations           | 82           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0028591997 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0544      |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.142        |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00305     |
# |    value_loss           | 0.18         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.9         |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 83          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.002711217 |
# |    clip_fraction        | 0.0192      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0564     |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.115       |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00133    |
# |    value_loss           | 0.205       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 783          |
# |    iterations           | 84           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0009970451 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0512      |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 830          |
# |    policy_gradient_loss | 0.00128      |
# |    value_loss           | 0.161        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 784          |
# |    iterations           | 85           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0022396755 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0536      |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0781       |
# |    n_updates            | 840          |
# |    policy_gradient_loss | 0.00086      |
# |    value_loss           | 0.193        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.9          |
# | time/                   |              |
# |    fps                  | 784          |
# |    iterations           | 86           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0014493153 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0512      |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0541       |
# |    n_updates            | 850          |
# |    policy_gradient_loss | 0.00166      |
# |    value_loss           | 0.162        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.84         |
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 87           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0029260602 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0439      |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0858       |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 0.168        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.9          |
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 88           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0009673143 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0559      |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0144       |
# |    n_updates            | 870          |
# |    policy_gradient_loss | 0.000702     |
# |    value_loss           | 0.189        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.94        |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 89          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.002084026 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0517     |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0754      |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 0.19        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.9          |
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 90           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0019987975 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0523      |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.13         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | 0.000821     |
# |    value_loss           | 0.193        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.86        |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 91          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.002294009 |
# |    clip_fraction        | 0.0145      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0517     |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.13        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | 0.000977    |
# |    value_loss           | 0.196       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.86         |
# | time/                   |              |
# |    fps                  | 786          |
# |    iterations           | 92           |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0018970073 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0475      |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0776       |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 0.195        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 787          |
# |    iterations           | 93           |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0021461681 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0511      |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.156        |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 0.195        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 787          |
# |    iterations           | 94           |
# |    time_elapsed         | 244          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0019526167 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0549      |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.176        |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.000863    |
# |    value_loss           | 0.206        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.84         |
# | time/                   |              |
# |    fps                  | 787          |
# |    iterations           | 95           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0017582306 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0462      |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0809       |
# |    n_updates            | 940          |
# |    policy_gradient_loss | 0.00501      |
# |    value_loss           | 0.175        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.88        |
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 96          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.001737248 |
# |    clip_fraction        | 0.0145      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0501     |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00253    |
# |    value_loss           | 0.188       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.84         |
# | time/                   |              |
# |    fps                  | 788          |
# |    iterations           | 97           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0022918792 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0469      |
# |    explained_variance   | 0.128        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0658       |
# |    n_updates            | 960          |
# |    policy_gradient_loss | 0.00145      |
# |    value_loss           | 0.182        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 788          |
# |    iterations           | 98           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0011561655 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0537      |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.11         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | 0.0011       |
# |    value_loss           | 0.198        |
# ------------------------------------------

# %%
i = 0
model2 = PPO.load('RL_uncertainty_model', UncertaintyEnv())
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
correct = 0
for i in range(len(test2_X)):
    obs = test2_X[i]
    p_gold = test2_y[i]
    pred, _ = model2.predict(obs)
    if pred==p_gold:
        correct += 1
accuracy2 = correct/len(test2_X)
print(accuracy2)
# Out:
# 0.9454610907781844

# %%
#model2.save('RL_uncertainty_model')
