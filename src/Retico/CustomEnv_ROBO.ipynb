# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install -q stable-baselines3[extra]
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 2.10.1 requires protobuf<5.0.0dev,>=3.20.1, but you have protobuf 3.19.5 which is incompatible.

# %%
import pickle
import numpy as np
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete
from stable_baselines3 import PPO
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %% [markdown]
# # 1. Action Model
#
# The action model predicts either a puzzle piece ID, to do nothing or to only forward the language group's output.

# %%
with open('data/X_DM.pickle', 'rb') as X_file:
    model1_X = pickle.load(X_file)
with open('data/y_DM.pickle', 'rb') as y_file:
    model1_y = pickle.load(y_file)

half = int(len(model1_X)/2)
train1_X, test1_X, train1_y, test1_y = train_test_split(model1_X[:half], model1_y[:half], test_size=1/3, random_state=42)

# %% [markdown]
# ## 1.1 Environment Definition

# %%
class ActionEnv(Env):
    def __init__(self):
        
        # ACTIONS
        '''an action can be to pick up one out of no_pieces pieces, do nothing or to forward the lang team output'''
        no_pieces = 15 + 1 + 1 
        self.action_space = Discrete(no_pieces)
        
        # OBSERVATIONS 
        '''currently we only observe the start state'''
        self.observation_space = Box(low=0, high=1, shape=(train1_X.shape[1],))

        # POSSIBLE STATES
        ''''here the start state is defined. since we used our synthetic data also for DL and testing the 
        rule based approach, we read in the data instead of creating them on the fly in every timestep.
        since init is called only once, this we only do here to initiate .state and .p_gold. the start state 
        needs to be '''
        self.state  = train1_X[i] # the output of previous groups at a given time
        self.p_gold = train1_y[i] # the correct action (the name is a bit confusing, because inititally we wanted to train the model to choose the highest probability)
 
        
    def step(self, action):
        '''Our actions do not cause a state transition, because we only have one state, the start state. 
        We only want to reward the correct action and punish a wrong one.
        '''
        if action == self.p_gold:
            reward = 1 
        else:
            reward = -1
        
        # Check if sequence is done
        '''since we currently play single-round games the game is over after chosing an action and receiving the reward'''
        done = True
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self):
        ''' if we'd play a game that makes sense to visuzalize like cartpole this would be done here'''
        pass
    
    def reset(self):
        '''here the start state is really defined.'''
        global i
        self.state = train1_X[i]
        self.p_gold = train1_y[i]
        i += 1
        if i == len(train1_X):
            i = 0

        return self.state

# %% [markdown]
# ## 1.2 Training

# %%
# i = 0
# model1 = PPO.load('RL_action_model', env=None)

# %%
i = 0
model1 = PPO("MlpPolicy", ActionEnv(), verbose=1)
model1.learn(total_timesteps=2/3*half)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.82    |
# | time/              |          |
# |    fps             | 1080     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.8        |
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012261825 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | -0.223      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0572      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0405     |
# |    value_loss           | 0.288       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.5        |
# | time/                   |             |
# |    fps                  | 752         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.118307576 |
# |    clip_fraction        | 0.416       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | -0.00752    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.114       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0731     |
# |    value_loss           | 0.324       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -0.16      |
# | time/                   |            |
# |    fps                  | 726        |
# |    iterations           | 4          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.11699866 |
# |    clip_fraction        | 0.568      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.23      |
# |    explained_variance   | 0.00145    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.229      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.125     |
# |    value_loss           | 0.65       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -0.02      |
# | time/                   |            |
# |    fps                  | 718        |
# |    iterations           | 5          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.10054589 |
# |    clip_fraction        | 0.647      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.68      |
# |    explained_variance   | 0.222      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.151      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.147     |
# |    value_loss           | 0.684      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.4        |
# | time/                   |            |
# |    fps                  | 736        |
# |    iterations           | 6          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.12099127 |
# |    clip_fraction        | 0.329      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | 0.382      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.224      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.115     |
# |    value_loss           | 0.582      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.5       |
# | time/                   |           |
# |    fps                  | 749       |
# |    iterations           | 7         |
# |    time_elapsed         | 19        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0374628 |
# |    clip_fraction        | 0.317     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.06     |
# |    explained_variance   | 0.473     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0614    |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -0.102    |
# |    value_loss           | 0.461     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.6         |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 8           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.051638804 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.789      |
# |    explained_variance   | 0.377       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.122       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.107      |
# |    value_loss           | 0.462       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.7        |
# | time/                   |            |
# |    fps                  | 747        |
# |    iterations           | 9          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.03105067 |
# |    clip_fraction        | 0.267      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.629     |
# |    explained_variance   | 0.293      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.102      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.092     |
# |    value_loss           | 0.422      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.8         |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 10          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.027354125 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.438      |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0967      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0795     |
# |    value_loss           | 0.347       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.8        |
# | time/                   |            |
# |    fps                  | 764        |
# |    iterations           | 11         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01931114 |
# |    clip_fraction        | 0.119      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.327     |
# |    explained_variance   | 0.123      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0519     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0586    |
# |    value_loss           | 0.3        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.96       |
# | time/                   |            |
# |    fps                  | 763        |
# |    iterations           | 12         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01708553 |
# |    clip_fraction        | 0.0733     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.236     |
# |    explained_variance   | 0.107      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0411     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0462    |
# |    value_loss           | 0.223      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.76        |
# | time/                   |             |
# |    fps                  | 777         |
# |    iterations           | 13          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006846226 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.205      |
# |    explained_variance   | 0.0251      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0925      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.033      |
# |    value_loss           | 0.234       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.88        |
# | time/                   |             |
# |    fps                  | 788         |
# |    iterations           | 14          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.012383515 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.159      |
# |    explained_variance   | 0.00943     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0771      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0331     |
# |    value_loss           | 0.216       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.82         |
# | time/                   |              |
# |    fps                  | 796          |
# |    iterations           | 15           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0075092656 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.146       |
# |    explained_variance   | 0.0392       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.155        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0253      |
# |    value_loss           | 0.191        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 803          |
# |    iterations           | 16           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0028210778 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.118       |
# |    explained_variance   | 0.0529       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0685       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.019       |
# |    value_loss           | 0.142        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.84         |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 17           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0036183363 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.107       |
# |    explained_variance   | 0.0797       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.048        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0211      |
# |    value_loss           | 0.147        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.88        |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 18          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.003990123 |
# |    clip_fraction        | 0.0278      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.1        |
# |    explained_variance   | 0.043       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0548      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 0.159       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 819          |
# |    iterations           | 19           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0031941722 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0963      |
# |    explained_variance   | 0.0679       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.053        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0194      |
# |    value_loss           | 0.151        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.9          |
# | time/                   |              |
# |    fps                  | 824          |
# |    iterations           | 20           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0026804782 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.102       |
# |    explained_variance   | 0.0767       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0302       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0163      |
# |    value_loss           | 0.134        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 21           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0035632765 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0932      |
# |    explained_variance   | 0.0472       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0517       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0195      |
# |    value_loss           | 0.13         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 831          |
# |    iterations           | 22           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0021615997 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0844      |
# |    explained_variance   | 0.0631       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0195       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0176      |
# |    value_loss           | 0.123        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 835          |
# |    iterations           | 23           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0030259618 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0749      |
# |    explained_variance   | 0.0707       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.035        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0168      |
# |    value_loss           | 0.142        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.96        |
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 24          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.003291516 |
# |    clip_fraction        | 0.0196      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0749     |
# |    explained_variance   | 0.062       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0701      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 0.137       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 832          |
# |    iterations           | 25           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0029355083 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0693      |
# |    explained_variance   | 0.0728       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0798       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.017       |
# |    value_loss           | 0.13         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 832          |
# |    iterations           | 26           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0031183092 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0734      |
# |    explained_variance   | 0.0564       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00721      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0168      |
# |    value_loss           | 0.111        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 834          |
# |    iterations           | 27           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0029899308 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0742      |
# |    explained_variance   | 0.0846       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0525       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.017       |
# |    value_loss           | 0.141        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.88         |
# | time/                   |              |
# |    fps                  | 834          |
# |    iterations           | 28           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0037151754 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0685      |
# |    explained_variance   | 0.0826       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.076        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0187      |
# |    value_loss           | 0.138        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.92        |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 29          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.003524474 |
# |    clip_fraction        | 0.0194      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0604     |
# |    explained_variance   | 0.0644      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00784     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 0.0988      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 780          |
# |    iterations           | 30           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0029329893 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0573      |
# |    explained_variance   | 0.0556       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.03         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.014       |
# |    value_loss           | 0.118        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 782          |
# |    iterations           | 31           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0025057234 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0472      |
# |    explained_variance   | 0.0746       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0543       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 0.0865       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.88         |
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 32           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0028900176 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.06        |
# |    explained_variance   | 0.0932       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0202       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0163      |
# |    value_loss           | 0.114        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.96        |
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 33          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.002485619 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0579     |
# |    explained_variance   | 0.0993      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0386      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 0.128       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 764          |
# |    iterations           | 34           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0036440515 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0626      |
# |    explained_variance   | 0.0814       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0289       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0174      |
# |    value_loss           | 0.136        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 760          |
# |    iterations           | 35           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0029623164 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0599      |
# |    explained_variance   | 0.0542       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0622       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0147      |
# |    value_loss           | 0.106        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 36           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0030859746 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0678      |
# |    explained_variance   | 0.0892       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0691       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0174      |
# |    value_loss           | 0.134        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 743          |
# |    iterations           | 37           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0028820143 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.053       |
# |    explained_variance   | 0.0631       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0641       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0133      |
# |    value_loss           | 0.0988       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.96        |
# | time/                   |             |
# |    fps                  | 740         |
# |    iterations           | 38          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004263258 |
# |    clip_fraction        | 0.0175      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0512     |
# |    explained_variance   | 0.0974      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00814     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 0.115       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.86         |
# | time/                   |              |
# |    fps                  | 739          |
# |    iterations           | 39           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0027870792 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0551      |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0648       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0175      |
# |    value_loss           | 0.103        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 743          |
# |    iterations           | 40           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0017390789 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0537      |
# |    explained_variance   | 0.102        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00653      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0124      |
# |    value_loss           | 0.0982       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.96        |
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 41          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.002981531 |
# |    clip_fraction        | 0.0126      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0466     |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000383    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.96        |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 42          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.002652898 |
# |    clip_fraction        | 0.0158      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0512     |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.03        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 0.109       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 746          |
# |    iterations           | 43           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0025376026 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0468      |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0063       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0131      |
# |    value_loss           | 0.101        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 748          |
# |    iterations           | 44           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0037235334 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0498      |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00387      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0164      |
# |    value_loss           | 0.11         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 750          |
# |    iterations           | 45           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0044844686 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0505      |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0707       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.017       |
# |    value_loss           | 0.113        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 749          |
# |    iterations           | 46           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0062231054 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0409      |
# |    explained_variance   | 0.0852       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0189       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0148      |
# |    value_loss           | 0.1          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.92         |
# | time/                   |              |
# |    fps                  | 750          |
# |    iterations           | 47           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0014426332 |
# |    clip_fraction        | 0.00811      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0387      |
# |    explained_variance   | 0.0686       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0425       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00879     |
# |    value_loss           | 0.0729       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.94        |
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 48          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.004271718 |
# |    clip_fraction        | 0.0202      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0527     |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00513     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 0.116       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 753          |
# |    iterations           | 49           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0035183192 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0551      |
# |    explained_variance   | 0.157        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00629      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0174      |
# |    value_loss           | 0.103        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 753          |
# |    iterations           | 50           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0024909694 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0371      |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0332       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0118      |
# |    value_loss           | 0.105        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 752          |
# |    iterations           | 51           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0035331724 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0472      |
# |    explained_variance   | 0.137        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0317       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0156      |
# |    value_loss           | 0.109        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 752          |
# |    iterations           | 52           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0021723239 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0426      |
# |    explained_variance   | 0.137        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00443      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 0.0911       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 752          |
# |    iterations           | 53           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0027339356 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0405      |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0309       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0146      |
# |    value_loss           | 0.104        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 755          |
# |    iterations           | 54           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0032301396 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0439      |
# |    explained_variance   | 0.151        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0769       |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0148      |
# |    value_loss           | 0.11         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.88         |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 55           |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.92        |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 309         |
# |    time_elapsed         | 874         |
# |    total_timesteps      | 632832      |
# | train/                  |             |
# |    approx_kl            | 0.002741964 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0141     |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0396      |
# |    n_updates            | 3080        |
# |    policy_gradient_loss | -0.00904    |
# |    value_loss           | 0.0703      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 310          |
# |    time_elapsed         | 878          |
# |    total_timesteps      | 634880       |
# | train/                  |              |
# |    approx_kl            | 0.0024839488 |
# |    clip_fraction        | 0.00996      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0138      |
# |    explained_variance   | 0.264        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0575       |
# |    n_updates            | 3090         |
# |    policy_gradient_loss | -0.00688     |
# |    value_loss           | 0.0733       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 311          |
# |    time_elapsed         | 881          |
# |    total_timesteps      | 636928       |
# | train/                  |              |
# |    approx_kl            | 0.0040190723 |
# |    clip_fraction        | 0.01         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0131      |
# |    explained_variance   | 0.342        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0104       |
# |    n_updates            | 3100         |
# |    policy_gradient_loss | -0.00775     |
# |    value_loss           | 0.0768       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.96        |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 312         |
# |    time_elapsed         | 883         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.002529122 |
# |    clip_fraction        | 0.00972     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0138     |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0111      |
# |    n_updates            | 3110        |
# |    policy_gradient_loss | -0.00821    |
# |    value_loss           | 0.0734      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.88         |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 313          |
# |    time_elapsed         | 886          |
# |    total_timesteps      | 641024       |
# | train/                  |              |
# |    approx_kl            | 0.0023597176 |
# |    clip_fraction        | 0.00933      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0131      |
# |    explained_variance   | 0.237        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0433       |
# |    n_updates            | 3120         |
# |    policy_gradient_loss | -0.00762     |
# |    value_loss           | 0.0727       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.94        |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 314         |
# |    time_elapsed         | 888         |
# |    total_timesteps      | 643072      |
# | train/                  |             |
# |    approx_kl            | 0.003143006 |
# |    clip_fraction        | 0.00947     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0118     |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 3130        |
# |    policy_gradient_loss | -0.00816    |
# |    value_loss           | 0.0718      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.94        |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 315         |
# |    time_elapsed         | 891         |
# |    total_timesteps      | 645120      |
# | train/                  |             |
# |    approx_kl            | 0.003949251 |
# |    clip_fraction        | 0.00835     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0138     |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0072     |
# |    n_updates            | 3140        |
# |    policy_gradient_loss | -0.00733    |
# |    value_loss           | 0.0654      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.9          |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 316          |
# |    time_elapsed         | 894          |
# |    total_timesteps      | 647168       |
# | train/                  |              |
# |    approx_kl            | 0.0039523365 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.015       |
# |    explained_variance   | 0.26         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0358       |
# |    n_updates            | 3150         |
# |    policy_gradient_loss | -0.01        |
# |    value_loss           | 0.0653       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 317         |
# |    time_elapsed         | 896         |
# |    total_timesteps      | 649216      |
# | train/                  |             |
# |    approx_kl            | 0.007869573 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.014      |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000491    |
# |    n_updates            | 3160        |
# |    policy_gradient_loss | -0.00969    |
# |    value_loss           | 0.0694      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 318          |
# |    time_elapsed         | 899          |
# |    total_timesteps      | 651264       |
# | train/                  |              |
# |    approx_kl            | 0.0032270406 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0134      |
# |    explained_variance   | 0.199        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0194       |
# |    n_updates            | 3170         |
# |    policy_gradient_loss | -0.00876     |
# |    value_loss           | 0.0777       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.94        |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 319         |
# |    time_elapsed         | 902         |
# |    total_timesteps      | 653312      |
# | train/                  |             |
# |    approx_kl            | 0.008508649 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.013      |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00575     |
# |    n_updates            | 3180        |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.072       |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1        |
# |    ep_rew_mean          | 0.9      |
# | time/                   |          |
# |    fps                  | 724      |
# |    iterations           | 320      |
# |    time_elapsed         | 904      |
# |    total_timesteps      | 655360   |
# | train/                  |          |
# |    approx_kl            | 0.004659 |
# |    clip_fraction        | 0.0128   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0145  |
# |    explained_variance   | 0.36     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0242   |
# |    n_updates            | 3190     |
# |    policy_gradient_loss | -0.00956 |
# |    value_loss           | 0.0687   |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.9         |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 321         |
# |    time_elapsed         | 907         |
# |    total_timesteps      | 657408      |
# | train/                  |             |
# |    approx_kl            | 0.003465844 |
# |    clip_fraction        | 0.0103      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0145     |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0196      |
# |    n_updates            | 3200        |
# |    policy_gradient_loss | -0.00768    |
# |    value_loss           | 0.0544      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 322          |
# |    time_elapsed         | 909          |
# |    total_timesteps      | 659456       |
# | train/                  |              |
# |    approx_kl            | 0.0039687236 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0178      |
# |    explained_variance   | 0.336        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0513       |
# |    n_updates            | 3210         |
# |    policy_gradient_loss | -0.00991     |
# |    value_loss           | 0.0861       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.9          |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 323          |
# |    time_elapsed         | 912          |
# |    total_timesteps      | 661504       |
# | train/                  |              |
# |    approx_kl            | 0.0023628378 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0133      |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0166       |
# |    n_updates            | 3220         |
# |    policy_gradient_loss | -0.00727     |
# |    value_loss           | 0.0716       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.98        |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 324         |
# |    time_elapsed         | 915         |
# |    total_timesteps      | 663552      |
# | train/                  |             |
# |    approx_kl            | 0.005341178 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0158     |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00824     |
# |    n_updates            | 3230        |
# |    policy_gradient_loss | -0.00849    |
# |    value_loss           | 0.064       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 325          |
# |    time_elapsed         | 918          |
# |    total_timesteps      | 665600       |
# | train/                  |              |
# |    approx_kl            | 0.0029617283 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0152      |
# |    explained_variance   | 0.338        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0481       |
# |    n_updates            | 3240         |
# |    policy_gradient_loss | -0.00884     |
# |    value_loss           | 0.0602       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 326          |
# |    time_elapsed         | 921          |
# |    total_timesteps      | 667648       |
# | train/                  |              |
# |    approx_kl            | 0.0063478574 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0139      |
# |    explained_variance   | 0.305        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0201       |
# |    n_updates            | 3250         |
# |    policy_gradient_loss | -0.00986     |
# |    value_loss           | 0.0815       |
# ------------------------------------------

# %%
model1.save('RL_action_model')

# %% [markdown]
# ## 1.3 Evaluation

# %%
i = 0

correct = 0
for i in tqdm(range(len(test1_X))):
    obs = test1_X[i]
    p_gold = test1_y[i]
    pred, _ = model1.predict(obs)
    if pred==p_gold:
        correct += 1
accuracy = correct/len(test1_X)
print(accuracy)
# Out:
# 100%|██████████| 333334/333334 [02:31<00:00, 2203.14it/s]
# 0.9723700552598895

# %% [markdown]
# # 2 Uncertainty Model
#
# This model predicts whether the action model is more likely predicting a correct or incorrect action.

# %%
model2_y = np.ones((half,))
for i in range(half, 2*half):
    obs = model1_X[i]
    p_gold = model1_y[i]
    pred, _ = model1.predict(obs)
    if pred==p_gold:
        model2_y[i-half] = 0
        
train2_X, test2_X, train2_y, test2_y = train_test_split(model1_X[half:], model2_y, test_size=1/3, random_state=42)

# %% [markdown]
# ## 2.1 Environment Definition

# %%
class UncertaintyEnv(Env):
    def __init__(self):
        # ACTIONS
        '''an action can be to predict either uncertainty (1) or certainty (0)'''
        self.action_space = Discrete(2)

        # OBSERVATION
        '''currently we only observe the start state'''

        self.observation_space = Box(low=0, high=1, shape=(train2_X.shape[1],))

        # POSSIBLE STATES
        ''''here the start state is defined. since we used our synthetic data also for DL and testing the 
        rule based approach, we read in the data instead of creating them on the fly in every timestep.
        since init is called only once, this we only do here to initiate .state and .p_gold. the start state 
        needs to be '''
        self.state  = train2_X[i]
        self.p_gold = train2_y[i]


    def step(self, action):
        '''Our actions do not cause a state transition, because we only have one state, the start state. 
        We only want to reward the correct action and punish a wrong one.
        '''        
        if action == self.p_gold:
            reward = 1
        else:
            reward = -1

        # Check if sequence is done
        '''since we currently play single-round games the game is over after chosing an action and receiving the reward'''

        done = True
        info = {}

        # Return step information
        return self.state, reward, done, info

    def render(self):
        ''' if we'd play a game that makes sense to visuzalize like cartpole this would be done here'''

        pass

    def reset(self):
        '''here the start state is really defined.'''
        global i
        
        self.state = train2_X[i]
        self.p_gold = train2_y[i]
        i += 1
        if i == len(train2_X):
            i = 0

        return self.state

# %% [markdown]
# ## 2.2 Training

# %%
# i = 0
# model2 = PPO.load('RL_uncertainty_model', env=None)

# %%
i = 0
model2 = PPO("MlpPolicy", UncertaintyEnv(), verbose=1)
model2.learn(total_timesteps=2/3*half)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.02    |
# | time/              |          |
# |    fps             | 1676     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.12        |
# | time/                   |             |
# |    fps                  | 1097        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.043866485 |
# |    clip_fraction        | 0.861       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | -0.113      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.333       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.162      |
# |    value_loss           | 1.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.72        |
# | time/                   |             |
# |    fps                  | 978         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.054622278 |
# |    clip_fraction        | 0.901       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.514      |
# |    explained_variance   | -0.014      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.273       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.167      |
# |    value_loss           | 0.897       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.82      |
# | time/                   |           |
# |    fps                  | 919       |
# |    iterations           | 4         |
# |    time_elapsed         | 8         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.1817316 |
# |    clip_fraction        | 0.558     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.184    |
# |    explained_variance   | -0.012    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.127     |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -0.133    |
# |    value_loss           | 0.687     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.96       |
# | time/                   |            |
# |    fps                  | 903        |
# |    iterations           | 5          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.17643556 |
# |    clip_fraction        | 0.0663     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0333    |
# |    explained_variance   | 0.0452     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0446     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0565    |
# |    value_loss           | 0.299      |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | 0.96          |
# | time/                   |               |
# |    fps                  | 884           |
# |    iterations           | 6             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00028230163 |
# |    clip_fraction        | 0.000928      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00757      |
# |    explained_variance   | -0.0851       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0594        |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000982     |
# |    value_loss           | 0.111         |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.92      |
# | time/                   |           |
# |    fps                  | 871       |
# |    iterations           | 7         |
# |    time_elapsed         | 16        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00568  |
# |    explained_variance   | 0.0208    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0348    |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -4.17e-06 |
# |    value_loss           | 0.115     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1        |
# |    ep_rew_mean          | 0.84     |
# | time/                   |          |
# |    fps                  | 860      |
# |    iterations           | 8        |
# |    time_elapsed         | 19       |
# |    total_timesteps      | 16384    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0051  |
# |    explained_variance   | 0.0122   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0309   |
# |    n_updates            | 70       |
# |    policy_gradient_loss | -5.4e-06 |
# |    value_loss           | 0.114    |
# --------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | 0.98          |
# | time/                   |               |
# |    fps                  | 840           |
# |    iterations           | 9             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00041416852 |
# |    clip_fraction        | 0.000879      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0023       |
# |    explained_variance   | 0.0193        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0058        |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00098      |
# |    value_loss           | 0.123         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.96         |
# | time/                   |              |
# |    fps                  | 827          |
# |    iterations           | 10           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 9.445002e-05 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0013      |
# |    explained_variance   | 0.00757      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0317       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00047     |
# |    value_loss           | 0.102        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 820          |
# |    iterations           | 11           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 5.166253e-05 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.000826    |
# |    explained_variance   | -0.00384     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00257      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000445    |
# |    value_loss           | 0.0784       |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.92      |
# | time/                   |           |
# |    fps                  | 812       |
# |    iterations           | 12        |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000814 |
# |    explained_variance   | 0.0292    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00441   |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -1.89e-08 |
# |    value_loss           | 0.114     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.98      |
# | time/                   |           |
# |    fps                  | 804       |
# |    iterations           | 13        |
# |    time_elapsed         | 33        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000783 |
# |    explained_variance   | 0.00722   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0558    |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -2.29e-07 |
# |    value_loss           | 0.0919    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 798       |
# |    iterations           | 14        |
# |    time_elapsed         | 35        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000744 |
# |    explained_variance   | 0.0279    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0288    |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -4.48e-08 |
# |    value_loss           | 0.0859    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 793       |
# |    iterations           | 15        |
# |    time_elapsed         | 38        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000743 |
# |    explained_variance   | 0.0416    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0837    |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -7.33e-08 |
# |    value_loss           | 0.105     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.9       |
# | time/                   |           |
# |    fps                  | 787       |
# |    iterations           | 16        |
# |    time_elapsed         | 41        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00072  |
# |    explained_variance   | 0.0421    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0266    |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -5.43e-08 |
# |    value_loss           | 0.0933    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.92      |
# | time/                   |           |
# |    fps                  | 783       |
# |    iterations           | 17        |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000692 |
# |    explained_variance   | 0.0364    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0336    |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -7.84e-08 |
# |    value_loss           | 0.0979    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 782       |
# |    iterations           | 18        |
# |    time_elapsed         | 47        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000678 |
# |    explained_variance   | 0.0511    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0326    |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -9.35e-08 |
# |    value_loss           | 0.0982    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 781       |
# |    iterations           | 19        |
# |    time_elapsed         | 49        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000645 |
# |    explained_variance   | 0.0456    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0848    |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -6.47e-08 |
# |    value_loss           | 0.103     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 781       |
# |    iterations           | 20        |
# |    time_elapsed         | 52        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000635 |
# |    explained_variance   | 0.0377    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0268    |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -8.48e-08 |
# |    value_loss           | 0.0964    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.92      |
# | time/                   |           |
# |    fps                  | 785       |
# |    iterations           | 21        |
# |    time_elapsed         | 54        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000612 |
# |    explained_variance   | 0.0457    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0296    |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -6.98e-08 |
# |    value_loss           | 0.106     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.92      |
# | time/                   |           |
# |    fps                  | 787       |
# |    iterations           | 22        |
# |    time_elapsed         | 57        |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000588 |
# |    explained_variance   | 0.0607    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0551    |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -5.37e-08 |
# |    value_loss           | 0.111     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.9       |
# | time/                   |           |
# |    fps                  | 790       |
# |    iterations           | 23        |
# |    time_elapsed         | 59        |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000568 |
# |    explained_variance   | 0.0533    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0788    |
# |    n_updates            | 220       |
# |    policy_gradient_loss | -1.07e-07 |
# |    value_loss           | 0.115     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 792       |
# |    iterations           | 24        |
# |    time_elapsed         | 61        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000523 |
# |    explained_variance   | 0.021     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0294    |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -1.75e-07 |
# |    value_loss           | 0.0888    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 795       |
# |    iterations           | 25        |
# |    time_elapsed         | 64        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000499 |
# |    explained_variance   | 0.0623    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0322    |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -4.19e-08 |
# |    value_loss           | 0.104     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 798       |
# |    iterations           | 26        |
# |    time_elapsed         | 66        |
# |    total_timesteps      | 53248     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000475 |
# |    explained_variance   | 0.0879    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00725   |
# |    n_updates            | 250       |
# |    policy_gradient_loss | -1.35e-07 |
# |    value_loss           | 0.0939    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.92      |
# | time/                   |           |
# |    fps                  | 800       |
# |    iterations           | 27        |
# |    time_elapsed         | 69        |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000435 |
# |    explained_variance   | 0.0682    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.146     |
# |    n_updates            | 260       |
# |    policy_gradient_loss | -1.15e-07 |
# |    value_loss           | 0.102     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 802       |
# |    iterations           | 28        |
# |    time_elapsed         | 71        |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000406 |
# |    explained_variance   | 0.0874    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0799    |
# |    n_updates            | 270       |
# |    policy_gradient_loss | -4.35e-08 |
# |    value_loss           | 0.104     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 804       |
# |    iterations           | 29        |
# |    time_elapsed         | 73        |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000382 |
# |    explained_variance   | 0.054     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.061     |
# |    n_updates            | 280       |
# |    policy_gradient_loss | -6.63e-08 |
# |    value_loss           | 0.0868    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.92      |
# | time/                   |           |
# |    fps                  | 806       |
# |    iterations           | 30        |
# |    time_elapsed         | 76        |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00036  |
# |    explained_variance   | 0.0614    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.029     |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -3.32e-08 |
# |    value_loss           | 0.0887    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 808       |
# |    iterations           | 31        |
# |    time_elapsed         | 78        |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000339 |
# |    explained_variance   | 0.0938    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.032     |
# |    n_updates            | 300       |
# |    policy_gradient_loss | -5.45e-08 |
# |    value_loss           | 0.0999    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 809       |
# |    iterations           | 32        |
# |    time_elapsed         | 80        |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000317 |
# |    explained_variance   | 0.0863    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0138    |
# |    n_updates            | 310       |
# |    policy_gradient_loss | -5.83e-09 |
# |    value_loss           | 0.107     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.86      |
# | time/                   |           |
# |    fps                  | 811       |
# |    iterations           | 33        |
# |    time_elapsed         | 83        |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000301 |
# |    explained_variance   | 0.082     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.124     |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -8.57e-08 |
# |    value_loss           | 0.0981    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.98      |
# | time/                   |           |
# |    fps                  | 812       |
# |    iterations           | 34        |
# |    time_elapsed         | 85        |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000281 |
# |    explained_variance   | 0.0999    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0691    |
# |    n_updates            | 330       |
# |    policy_gradient_loss | -2.62e-08 |
# |    value_loss           | 0.0984    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.98      |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 35        |
# |    time_elapsed         | 88        |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000254 |
# |    explained_variance   | 0.0435    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0535    |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -7.04e-08 |
# |    value_loss           | 0.075     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 815       |
# |    iterations           | 36        |
# |    time_elapsed         | 90        |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000228 |
# |    explained_variance   | 0.0969    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0282    |
# |    n_updates            | 350       |
# |    policy_gradient_loss | -3.63e-08 |
# |    value_loss           | 0.0926    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 817       |
# |    iterations           | 37        |
# |    time_elapsed         | 92        |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000207 |
# |    explained_variance   | 0.0754    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.116     |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -9.05e-08 |
# |    value_loss           | 0.0701    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 818       |
# |    iterations           | 38        |
# |    time_elapsed         | 95        |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00019  |
# |    explained_variance   | 0.0947    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0664    |
# |    n_updates            | 370       |
# |    policy_gradient_loss | -2.45e-09 |
# |    value_loss           | 0.0887    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 819       |
# |    iterations           | 39        |
# |    time_elapsed         | 97        |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000172 |
# |    explained_variance   | 0.0475    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0293    |
# |    n_updates            | 380       |
# |    policy_gradient_loss | -8.12e-08 |
# |    value_loss           | 0.0691    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 820       |
# |    iterations           | 40        |
# |    time_elapsed         | 99        |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000158 |
# |    explained_variance   | 0.0766    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0541    |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -4.57e-09 |
# |    value_loss           | 0.085     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.98      |
# | time/                   |           |
# |    fps                  | 821       |
# |    iterations           | 41        |
# |    time_elapsed         | 102       |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000152 |
# |    explained_variance   | 0.111     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.047     |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -8.65e-09 |
# |    value_loss           | 0.105     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 822       |
# |    iterations           | 42        |
# |    time_elapsed         | 104       |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000131 |
# |    explained_variance   | 0.113     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0727    |
# |    n_updates            | 410       |
# |    policy_gradient_loss | -6.16e-08 |
# |    value_loss           | 0.0969    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 823       |
# |    iterations           | 43        |
# |    time_elapsed         | 106       |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00012  |
# |    explained_variance   | 0.0932    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.048     |
# |    n_updates            | 420       |
# |    policy_gradient_loss | -9.02e-10 |
# |    value_loss           | 0.105     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.98      |
# | time/                   |           |
# |    fps                  | 823       |
# |    iterations           | 44        |
# |    time_elapsed         | 109       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000113 |
# |    explained_variance   | 0.0951    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00684   |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -2.28e-08 |
# |    value_loss           | 0.0835    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.98      |
# | time/                   |           |
# |    fps                  | 823       |
# |    iterations           | 45        |
# |    time_elapsed         | 111       |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000102 |
# |    explained_variance   | 0.0848    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0518    |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -2.24e-08 |
# |    value_loss           | 0.0719    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 824       |
# |    iterations           | 46        |
# |    time_elapsed         | 114       |
# |    total_timesteps      | 94208     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -9.54e-05 |
# |    explained_variance   | 0.134     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0482    |
# |    n_updates            | 450       |
# |    policy_gradient_loss | -2.72e-09 |
# |    value_loss           | 0.0888    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 825       |
# |    iterations           | 47        |
# |    time_elapsed         | 116       |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -8.7e-05  |
# |    explained_variance   | 0.0935    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0425    |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -1.84e-08 |
# |    value_loss           | 0.0838    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 826       |
# |    iterations           | 48        |
# |    time_elapsed         | 118       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.66e-05 |
# |    explained_variance   | 0.101     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.048     |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -2.21e-08 |
# |    value_loss           | 0.0922    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 827       |
# |    iterations           | 49        |
# |    time_elapsed         | 121       |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.31e-05 |
# |    explained_variance   | 0.148     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0497    |
# |    n_updates            | 480       |
# |    policy_gradient_loss | 1.2e-09   |
# |    value_loss           | 0.0976    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.92      |
# | time/                   |           |
# |    fps                  | 827       |
# |    iterations           | 50        |
# |    time_elapsed         | 123       |
# |    total_timesteps      | 102400    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.77e-05 |
# |    explained_variance   | 0.0951    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0961    |
# |    n_updates            | 490       |
# |    policy_gradient_loss | -1.42e-08 |
# |    value_loss           | 0.0779    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 828       |
# |    iterations           | 51        |
# |    time_elapsed         | 126       |
# |    total_timesteps      | 104448    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.37e-05 |
# |    explained_variance   | 0.133     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00825   |
# |    n_updates            | 500       |
# |    policy_gradient_loss | -8.98e-10 |
# |    value_loss           | 0.0957    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 828       |
# |    iterations           | 52        |
# |    time_elapsed         | 128       |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.01e-05 |
# |    explained_variance   | 0.0738    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0661    |
# |    n_updates            | 510       |
# |    policy_gradient_loss | -1.08e-08 |
# |    value_loss           | 0.074     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 828       |
# |    iterations           | 53        |
# |    time_elapsed         | 131       |
# |    total_timesteps      | 108544    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.47e-05 |
# |    explained_variance   | 0.168     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0454    |
# |    n_updates            | 520       |
# |    policy_gradient_loss | 3.29e-09  |
# |    value_loss           | 0.0903    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.98      |
# | time/                   |           |
# |    fps                  | 828       |
# |    iterations           | 54        |
# |    time_elapsed         | 133       |
# |    total_timesteps      | 110592    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.17e-05 |
# |    explained_variance   | 0.137     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0425    |
# |    n_updates            | 530       |
# |    policy_gradient_loss | -1.08e-08 |
# |    value_loss           | 0.0743    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.98      |
# | time/                   |           |
# |    fps                  | 828       |
# |    iterations           | 55        |
# |    time_elapsed         | 135       |
# |    total_timesteps      | 112640    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.88e-05 |
# |    explained_variance   | 0.138     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0231    |
# |    n_updates            | 540       |
# |    policy_gradient_loss | -1.63e-09 |
# |    value_loss           | 0.0934    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 825       |
# |    iterations           | 56        |
# |    time_elapsed         | 138       |
# |    total_timesteps      | 114688    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.81e-05 |
# |    explained_variance   | 0.176     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.028     |
# |    n_updates            | 550       |
# |    policy_gradient_loss | -1.12e-09 |
# |    value_loss           | 0.101     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 823       |
# |    iterations           | 57        |
# |    time_elapsed         | 141       |
# |    total_timesteps      | 116736    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.39e-05 |
# |    explained_variance   | 0.145     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0283    |
# |    n_updates            | 560       |
# |    policy_gradient_loss | -1.89e-09 |
# |    value_loss           | 0.0822    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# ...
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 308       |
# |    time_elapsed         | 774       |
# |    total_timesteps      | 630784    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.25e-06 |
# |    explained_variance   | 0.307     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0309    |
# |    n_updates            | 3070      |
# |    policy_gradient_loss | -1.09e-10 |
# |    value_loss           | 0.0649    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.92      |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 309       |
# |    time_elapsed         | 777       |
# |    total_timesteps      | 632832    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.23e-06 |
# |    explained_variance   | 0.306     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00443   |
# |    n_updates            | 3080      |
# |    policy_gradient_loss | -1.18e-09 |
# |    value_loss           | 0.0669    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1        |
# |    ep_rew_mean          | 0.9      |
# | time/                   |          |
# |    fps                  | 814      |
# |    iterations           | 310      |
# |    time_elapsed         | 779      |
# |    total_timesteps      | 634880   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -3.2e-06 |
# |    explained_variance   | 0.286    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0267   |
# |    n_updates            | 3090     |
# |    policy_gradient_loss | 1.24e-09 |
# |    value_loss           | 0.0772   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 311       |
# |    time_elapsed         | 782       |
# |    total_timesteps      | 636928    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.19e-06 |
# |    explained_variance   | 0.274     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0653    |
# |    n_updates            | 3100      |
# |    policy_gradient_loss | -2.4e-10  |
# |    value_loss           | 0.0726    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.98      |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 312       |
# |    time_elapsed         | 784       |
# |    total_timesteps      | 638976    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.27e-06 |
# |    explained_variance   | 0.289     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0136    |
# |    n_updates            | 3110      |
# |    policy_gradient_loss | 5.97e-10  |
# |    value_loss           | 0.0821    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 313       |
# |    time_elapsed         | 787       |
# |    total_timesteps      | 641024    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.13e-06 |
# |    explained_variance   | 0.292     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.056     |
# |    n_updates            | 3120      |
# |    policy_gradient_loss | 1.21e-09  |
# |    value_loss           | 0.0704    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 314       |
# |    time_elapsed         | 789       |
# |    total_timesteps      | 643072    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.17e-06 |
# |    explained_variance   | 0.289     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0224    |
# |    n_updates            | 3130      |
# |    policy_gradient_loss | 1.84e-11  |
# |    value_loss           | 0.0696    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.98      |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 315       |
# |    time_elapsed         | 791       |
# |    total_timesteps      | 645120    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.16e-06 |
# |    explained_variance   | 0.294     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00986   |
# |    n_updates            | 3140      |
# |    policy_gradient_loss | -3.2e-10  |
# |    value_loss           | 0.0747    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 316       |
# |    time_elapsed         | 794       |
# |    total_timesteps      | 647168    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.23e-06 |
# |    explained_variance   | 0.29      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0251    |
# |    n_updates            | 3150      |
# |    policy_gradient_loss | 9.5e-10   |
# |    value_loss           | 0.0768    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 1         |
# | time/                   |           |
# |    fps                  | 815       |
# |    iterations           | 317       |
# |    time_elapsed         | 796       |
# |    total_timesteps      | 649216    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.23e-06 |
# |    explained_variance   | 0.32      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.021     |
# |    n_updates            | 3160      |
# |    policy_gradient_loss | 3.91e-10  |
# |    value_loss           | 0.0609    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.88      |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 318       |
# |    time_elapsed         | 799       |
# |    total_timesteps      | 651264    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.3e-06  |
# |    explained_variance   | 0.251     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0417    |
# |    n_updates            | 3170      |
# |    policy_gradient_loss | -2.06e-10 |
# |    value_loss           | 0.0718    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.92      |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 319       |
# |    time_elapsed         | 801       |
# |    total_timesteps      | 653312    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.24e-06 |
# |    explained_variance   | 0.147     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0476    |
# |    n_updates            | 3180      |
# |    policy_gradient_loss | 5.05e-10  |
# |    value_loss           | 0.0674    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.92      |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 320       |
# |    time_elapsed         | 804       |
# |    total_timesteps      | 655360    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.24e-06 |
# |    explained_variance   | 0.181     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0177    |
# |    n_updates            | 3190      |
# |    policy_gradient_loss | -1.03e-09 |
# |    value_loss           | 0.0578    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 815       |
# |    iterations           | 321       |
# |    time_elapsed         | 806       |
# |    total_timesteps      | 657408    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.24e-06 |
# |    explained_variance   | 0.269     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0238    |
# |    n_updates            | 3200      |
# |    policy_gradient_loss | 1.56e-09  |
# |    value_loss           | 0.0746    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 815       |
# |    iterations           | 322       |
# |    time_elapsed         | 809       |
# |    total_timesteps      | 659456    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.27e-06 |
# |    explained_variance   | 0.344     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0265    |
# |    n_updates            | 3210      |
# |    policy_gradient_loss | -9.71e-11 |
# |    value_loss           | 0.0732    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.9       |
# | time/                   |           |
# |    fps                  | 815       |
# |    iterations           | 323       |
# |    time_elapsed         | 811       |
# |    total_timesteps      | 661504    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.21e-06 |
# |    explained_variance   | 0.354     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0522    |
# |    n_updates            | 3220      |
# |    policy_gradient_loss | 1.22e-09  |
# |    value_loss           | 0.0654    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 815       |
# |    iterations           | 324       |
# |    time_elapsed         | 813       |
# |    total_timesteps      | 663552    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.16e-06 |
# |    explained_variance   | 0.287     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0167    |
# |    n_updates            | 3230      |
# |    policy_gradient_loss | 1.71e-11  |
# |    value_loss           | 0.0642    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.94      |
# | time/                   |           |
# |    fps                  | 815       |
# |    iterations           | 325       |
# |    time_elapsed         | 816       |
# |    total_timesteps      | 665600    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.18e-06 |
# |    explained_variance   | 0.325     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0355    |
# |    n_updates            | 3240      |
# |    policy_gradient_loss | -7.23e-10 |
# |    value_loss           | 0.0875    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.96      |
# | time/                   |           |
# |    fps                  | 815       |
# |    iterations           | 326       |
# |    time_elapsed         | 818       |
# |    total_timesteps      | 667648    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.24e-06 |
# |    explained_variance   | 0.223     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0486    |
# |    n_updates            | 3250      |
# |    policy_gradient_loss | -7.33e-10 |
# |    value_loss           | 0.0914    |
# ---------------------------------------

# %%
model2.save('RL_uncertainty_model')

# %% [markdown]
# ## 2.3 Evaluation

# %%
i = 0

correct = 0
for i in tqdm(range(len(test2_X))):
    obs = test2_X[i]
    p_gold = test2_y[i]
    pred, _ = model2.predict(obs)
    if pred==p_gold:
        correct += 1
accuracy2 = correct/len(test2_X)
print(accuracy2)
# Out:
# 100%|██████████| 333334/333334 [02:11<00:00, 2527.83it/s]
# 0.972004055991888
